# %% [markdown]
# # Hillslope Mesh

# %%
import tinerator as tin
import numpy as np
from matplotlib import pyplot as plt
import ipywidgets as widgets
# %matplotlib widget

# pip install ipympl
# pip install ipywidgets (optional?)
# jupyter labextension install @jupyter-widgets/jupyterlab-manager
# jupyter labextension install jupyter-matplotlib
# jupyter lab build

# %%
def f(x, y, xv, zv, v_slope, y0, stream_slope):
    z = zv + v_slope*np.abs(x-xv) + (y-y0)*stream_slope
    return z

def make_mesh(
    stream_slope = 0.05,
    nx=11,
    ny=21,
    x_min=0.0,
    x_max=10.0,
    y_min=0.0,
    y_max=20.0,
    z_min=0.0,
    z_v=7.0,
    z_max=10.0,
):
    x_v = (x_max - x_min) / 2.
    dx = (x_max - x_min) / (nx - 1)
    dy = (y_max - y_min) / (ny - 1)
    
    v_slope = (z_max - z_v) / x_v
    
    x = np.linspace(x_min, x_max, nx)
    y = np.linspace(y_min, y_max, ny)
    X, Y = np.meshgrid(x, y)
    
    Z = f(X, Y, x_v, z_v, v_slope, y_min, stream_slope)
    
    return x, y, Z


# The external 'widgets.py' file will
#   compute `make_mesh` with widget functionality
# The parameter `s.xyZ()` returns the x, y, Z data
# %run -i widgets.py
mm_widget = MakeMeshWidget()
display(mm_widget)
# Out:
# MakeMeshWidget(children=(VBox(children=(Label(value='Discretization'), IntSlider(value=11, continuous_update=F…

# %% [markdown]
# # Use the computed x, y, Z values to construct a hillslope mesh

# %%
x, y, Z = mm_widget.xyZ()

# Alternately, you can use the function directly:
# =============================== #
# x, y, Z = make_mesh(
#     nx=12,
#     ny=21,
#     stream_slope=0.05,
#     x_min=0.0,
#     x_max=10.0,
#     y_min=0.0,
#     y_max=20.0,
#     z_min=0.0,
#     z_max=10.0,
#     z_v=7.0,
# )

quad_mesh = tin.meshing.create_hillslope_mesh(
    Z, x_coords=x, y_coords=y
)
quad_mesh.view()
# Out:
# [00:17:35] Hillslope and quad meshes are an experimental feature.              ]8;id=1630045055.0364978-548160;file:///Users/livingston/dev/lanl/tinerator/tinerator/logging.py\logging.py]8;;\:126
#            Expect things to break.                                             ]8;id=1630045055.039532-326500;file:///Users/livingston/dev/lanl/tinerator/tinerator/logging.py\logging.py]8;;\:126
# <div id='1034'>
#
#
#
#
#
#   <div class="bk-root" id="7c631103-d508-474d-a4f9-f811dc8f93d4" data-root-id="1034"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"a4de52cc-8bd9-4504-a0d7-785991912f0e":{"defs":[],"roots":{"references":[{"attributes":{"arrays":{"359c23e261d195a87ccb08baee29752a":"UEsDBBQAAAAIADECG1Ny/EIpDgAAAHADAAAlAAAAZGF0YS8zNTljMjNlMjYxZDE5NWE4N2NjYjA4YmFlZTI5NzUyYWNkYGBgHMWjeBTTBQMAUEsBAhQDFAAAAAgAMQIbU3L8QikOAAAAcAMAACUAAAAAAAAAAAAAAIABAAAAAGRhdGEvMzU5YzIzZTI2MWQxOTVhODdjY2IwOGJhZWUyOTc1MmFQSwUGAAAAAAEAAQBTAAAAUQAAAAAA","cd0712c7110270617a45feda5b044687":"...","ce52d598102e2756143cf4f27a0b5911":"...","f59e3b91770b0fa474e58e6f8a1ececa":"..."},"axes":{"id":"1033"},"color_mappers":[{"id":"1032"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce5888f650}"]],["addRenderer",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce58890560}"]],["addRenderer",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b5790}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00007fce5888ff90}"]],["addViewProp",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b96c0}"]]],"dependencies":[{"id":"00007fce5888ff90","parent":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce5888f650","properties":{"clippingRange":[23.98050561780898,68.83967518217543],"focalPoint":[5.0,10.0,9.136363636363637],"position":[30.28420555046209,35.28420555046209,34.42056918682573],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630}"]],["setProperty",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b98a0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630-dataset-0}",0]],["setLookupTable",["instance:${0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b93d0}"]]],"dependencies":[{"id":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630-dataset-0","parent":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630","properties":{"fields":[{"dataType":"Int32Array","hash":"359c23e261d195a87ccb08baee29752a","location":"cellData","name":"material_id","numberOfComponents":1,"ranges":[{"component":null,"max":1.0,"min":1.0}],"registration":"setScalars","size":220,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"cd0712c7110270617a45feda5b044687","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":10.0,"min":0.0},{"component":null,"max":20.0,"min":0.0},{"component":null,"max":11.0,"min":7.2727272727272725},{"component":null,"max":24.919871588754223,"min":8.576346483687821}],"size":756,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"f59e3b91770b0fa474e58e6f8a1ececa","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":251.0,"min":0.0}],"size":1100,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b93d0","parent":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[1.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[1.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTable"}],"id":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b8630","parent":"0a6cd717-5aed-442b-972c-7fa3195f9c6000007fce588b96c0","properties":{"arrayAccessMode":1,"colorByArrayName":null,"colorMode":1,"interpolateScala ...

# %% [markdown]
# # Extrude from a quad surface mesh to a hexahedron volume mesh

# %%
z_min = 0.0
n_z = 11

layers = [("snapped", z_min, n_z, 1),]
hex_mesh = tin.meshing.extrude_mesh(quad_mesh, layers)
hex_mesh.view()
# Out:
# <div id='1039'>
#
#
#
#
#
#   <div class="bk-root" id="c818241d-af78-4fcf-8810-2a892889e523" data-root-id="1039"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"aa767f94-5eda-4be5-82f4-57fba6f39c5f":{"defs":[],"roots":{"references":[{"attributes":{"digits":3,"grid_opacity":0.5,"origin":[0.0,0.0,0.0],"xticker":{"ticks":[0.0,2.5,5.0,7.5,10.0]},"yticker":{"ticks":[0.0,5.0,10.0,15.0,20.0]},"zticker":{"ticks":[0.0,2.75,5.5,8.25,11.0]}},"id":"1038","type":"panel.models.vtk.VTKAxes"},{"attributes":{"arrays":{"64c1859e8a115551e4402c2a43df5faa":"...","999dfad1153e0f624e0b4e68c79292f8":"...","9b7f68b069f31a1d035dd95d5307c16c":"","ce52d598102e2756143cf4f27a0b5911":"..."},"axes":{"id":"1038"},"color_mappers":[{"id":"1037"}],"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58caf920}"]],["addRenderer",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58ca9c70}"]],["addRenderer",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd18d0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00007fce58ca9080}"]],["addViewProp",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd5800}"]]],"dependencies":[{"id":"00007fce58ca9080","parent":"63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58caf920","properties":{"clippingRange":[24.10707592807134,78.51199723599163],"focalPoint":[5.0,10.0,5.5],"position":[32.794505161394,37.794505161394,33.294505161394],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd4770}"]],["setProperty",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd59e0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd4770-dataset-0}",0]],["setLookupTable",["instance:${63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd5510}"]]],"dependencies":[{"id":"63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd4770-dataset-0","parent":"63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd4770","properties":{"fields":[{"dataType":"Int32Array","hash":"9b7f68b069f31a1d035dd95d5307c16c","location":"cellData","name":"material_id","numberOfComponents":1,"ranges":[{"component":null,"max":1.0,"min":1.0}],"registration":"setScalars","size":1122,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float64Array","hash":"999dfad1153e0f624e0b4e68c79292f8","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":10.0,"min":0.0},{"component":null,"max":20.0,"min":0.0},{"component":null,"max":11.0,"min":0.0},{"component":null,"max":24.919871588754223,"min":0.0}],"size":9072,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"64c1859e8a115551e4402c2a43df5faa","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":3023.0,"min":0.0}],"size":5610,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min":30.0},{"component":null,"max":231.0,"min":1.0},{"component":null,"max":142.0,"min":24.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":428.5918804643877,"min":276.95848064285735}],"registration":"setTable","size":1024,"vtkClass":"vtkDataArray"}],"id":"63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd5510","parent":"63bd2234-0ac6-4e7c-b1a0-3aaaf9c1237600007fce58cd4770","properties":{"aboveRangeColor":[1.0,1.0,1.0,1.0],"alpha":1.0,"belowRangeColor":[0.0,0.0,0.0,1.0],"hueRange":[0.5,0],"indexedLookup":0,"nanColor":[0.6627450980392157,0.6627450980392157,0.6627450980392157,1.0],"numberOfColors":256,"range":[1.0,1.0],"saturationRange":[1.0,1.0],"useAboveRangeColor":false,"useBelowRangeColor":false,"valueRange":[1.0,1.0],"vectorComponent":0,"vectorMode":1,"vectorSize":-1},"type":"vtkLookupTab ...

# %% [markdown]
# # Create face sets and write to ExodusII file

# %%
surface_mesh = hex_mesh.surface_mesh()

set_top = surface_mesh.top_faces
sets_normals = surface_mesh.from_cell_normals()

sets = sets_normals + [set_top]

hex_mesh.view(sets=sets)
hex_mesh.save("Open-Book-3D.exo", sets=sets)
# Out:
# <div id='1043'>
#
#
#
#
#
#   <div class="bk-root" id="e13c47d5-8472-4699-aa23-ecaa024543d0" data-root-id="1043"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"53a0da9a-1b4a-4970-8205-1343ee141d66":{"defs":[],"roots":{"references":[{"attributes":{"client_comm_id":"67cdc406a2fe4bd2aa9e28eee69f1e17","comm_id":"e489c1a6b3cb456ca618b33f491f358f","plot_id":"1043"},"id":"1044","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"03813f7fccc856ac862887507d579315":"...","2ebda7d3c6c3627ba233a85b7027cd58":"...","2fdc522738d0e92c0424f444cc5a9a14":"...","5248ead936433ec5823c79ea591a8203":"...","64c1859e8a115551e4402c2a43df5faa":"...","7ff03b30b68999767b1a50f73be5a830":"...","8f53a55742c011b05c7e4a5aa56367a9":"","9c7aa3ff710fdb5e18c5fbffd281b7b7":"...","c6ce630edf5b6c1f3a5af3897ef9d9e7":"...","ce52d598102e2756143cf4f27a0b5911":"...","efc8949fe7611ba6fa4f85794413c3b7":"...","f59e3b91770b0fa474e58e6f8a1ececa":"..."},"axes":{"id":"1042"},"color_mappers":[{"id":"1041"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce57d3b4d0}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a172680}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a1763f0}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a1788b0}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a17ad70}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a17d230}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a17f6f0}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a181bb0}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a184070}"]],["addRenderer",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a186530}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${00007fce74bdab70}"]],["addViewProp",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a1af830}"]]],"dependencies":[{"id":"00007fce74bdab70","parent":"c1e07167-2200-4675-83ca-d5b02c43973d00007fce57d3b4d0","properties":{"clippingRange":[40.351443904397826,49.841117155961626],"focalPoint":[5.0,10.0,5.5],"position":[5.0,10.0,53.6414951107698],"viewUp":[0.0,1.0,0.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a189320}"]],["setProperty",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a1afa10}"]]],"dependencies":[{"calls":[["setInputData",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a189320-dataset-0}",0]],["setLookupTable",["instance:${c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a1af540}"]]],"dependencies":[{"id":"c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a189320-dataset-0","parent":"c1e07167-2200-4675-83ca-d5b02c43973d00007fce5a189320","properties":{"fields":[{"dataType":"Int32Array","hash":"8f53a55742c011b05c7e4a5aa56367a9","location":"cellData","name":"material_id","numberOfComponents":1,"ranges":[{"component":null,"max":1.0,"min":1.0}],"registration":"setScalars","size":1122,"vtkClass":"vtkDataArray"}],"points":{"dataType":"Float32Array","hash":"efc8949fe7611ba6fa4f85794413c3b7","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":10.0,"min":0.0},{"component":null,"max":20.0,"min":0.0},{"component":null,"max":11.0,"min":0.0},{"component":null,"max":24.919871588754223,"min":0.0}],"size":9072,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Array","hash":"64c1859e8a115551e4402c2a43df5faa","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":3023.0,"min":0.0}],"size":5610,"vtkClass":"vtkCellArray"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ce52d598102e2756143cf4f27a0b5911","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":253.0,"min ...
# north: min = 210; max = 2420
# south: min = 1; max = 2211
# east: min = 11; max = 2420
# west: min = 1; max = 2410
# up: min = 6; max = 215
# down: min = 2201; max = 2420
# TopFaces: min = 1; max = 220
# Opening exodus file: Open-Book-3D-nx12.exo
# Closing exodus file: Open-Book-3D-nx12.exo
# EXODUS write was successful.
