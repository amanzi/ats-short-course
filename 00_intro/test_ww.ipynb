# %%
# %matplotlib ipympl

# %%
# do libraries import correctly?  If not, make sure your kernel is the watershed_workflow kernel
import shapely
import geopandas
import py3dep

# %%
box = shapely.geometry.box(-83.01, 39.0, -83.0, 39.01)

# %%
# confirm that requests and aiohttp work correctly -- if not, see troubleshooting
dem = py3dep.get_map(['DEM',], box, 60, 4326, 5070)

# %%
# confirm you can plot, zoom, resize, etc
dem.plot.imshow()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# confirm you can import watershed_workflow
import watershed_workflow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # confirm you can import watershed_workflow
# ----> 2 import watershed_workflow
#
# File ~/code/watershed_workflow/repos/master/watershed_workflow/__init__.py:36
#      34 import watershed_workflow.crs
#      35 import watershed_workflow.utils
# ---> 36 import watershed_workflow.sources
#      37 import watershed_workflow.sources.standard_names as names
#      39 import watershed_workflow.river_tree
#
# File ~/code/watershed_workflow/repos/master/watershed_workflow/sources/__init__.py:30
#      28 # DayMet THREDDS API is disabled -- this only works for previously-downloaded files!
#      29 from .manager_daymet import ManagerDaymet
# ---> 30 from .manager_aorc import ManagerAORC
#      32 from .manager_modis_appeears import ManagerMODISAppEEARS
#      35 # available and default water boundary datasets
# ...
